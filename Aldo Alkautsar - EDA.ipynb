# %% [markdown]
# # Practice Case - EDA

# %% [markdown]
# ## iykra Data Fellowship Batch 6
# by Aldo Alkautsar

# %%
# import library
import pandas as pd

# %%
df = pd.read_csv('epl_1819.csv')
df
# Out:
#                  Team                        category  \
# 0     Manchester City                Champions League
# 1           Liverpool                Champions League
# 2             Chelsea  Champions League Qualification
# 3           Tottenham  Champions League Qualification
# 4             Arsenal                   Europa League
# 5   Manchester United                   Europa League
# 6       Wolverhampton     Europa League Qualification
# 7             Everton            No UEFA Competitions
# 8           Leicester            No UEFA Competitions
# 9            West Ham            No UEFA Competitions
# 10            Watford            No UEFA Competitions
# 11     Crystal Palace            No UEFA Competitions
# 12          Newcastle            No UEFA Competitions
# 13        Bournemouth            No UEFA Competitions
# 14            Burnley            No UEFA Competitions
# 15        Southampton            No UEFA Competitions
# ...

# %% [markdown]
# ### Data Understanding

# %%
df.columns
# Out:
# Index(['Team', 'category', 'general_league_position',
#        'finance _live_games_televised', 'finance _tv_revenue',
#        'general_matches_played', 'general_won', 'general_draw', 'general_lost',
#        'attack_scored', 'defence_goals_conceeded', 'general_goal_difference',
#        'general_points', 'general_squad_size', 'general_squad_average_age',
#        'general_squad_foreigners', 'finance _team_market',
#        'finance _market_average', 'attack_passes', 'attack_passes_through',
#        'attack_passes_long', 'attack_passes_back', 'attack_crosses',
#        'attack_corners_taken', 'attack_shots', 'attack_shots_on_target',
#        'attack_goals_headed', 'attack_goals_penalty', 'attack_goals_box',
#        'attack_goals_outsidebox', 'general_card_yellow', 'general_card_red',
#        'attack_goals_counter', 'attack_goals_freekick', 'defence_saves',
#        'defence_blocks', 'defence_interceptions', 'defence_tackles',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 44 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Team                           20 non-null     object
#  1   category                       20 non-null     object
#  2   general_league_position        20 non-null     int64
#  3   finance _live_games_televised  20 non-null     int64
#  4   finance _tv_revenue            20 non-null     int64
#  5   general_matches_played         20 non-null     int64
#  6   general_won                    20 non-null     int64
#  7   general_draw                   20 non-null     int64
#  8   general_lost                   20 non-null     int64
#  9   attack_scored                  20 non-null     int64
#  10  defence_goals_conceeded        20 non-null     int64
#  11  general_goal_difference        20 non-null     int64
# ...

# %%
df[['attack_passes','attack_passes_long','attack_passes_back','defence_clearances']]
# Out:
#    attack_passes attack_passes_long attack_passes_back defence_clearances
# 0         26,581              1,814              4,240                543
# 1         23,638              2,250              3,416                639
# 2         25,070              1,774              3,874                593
# 3         21,295              2,267              3,191                770
# 4         20,805              2,062              3,102                762
# 5         19,202              2,242              2,634                785
# 6         16,618              2,552              2,515                824
# 7         16,494              2,310              2,362                825
# 8         17,219              2,335              2,593                945
# 9         16,358              2,315              2,273                855
# 10        15,462              2,437              2,314                956
# 11        15,243              2,259              2,233                940
# ...

# %% [markdown]
# change the data type

# %%
df['attack_passes'] = df['attack_passes'].str.replace(',', '').astype(float)
df['attack_passes_long'] = df['attack_passes_long'].str.replace(',', '').astype(float)
df['attack_passes_back'] = df['attack_passes_back'].str.replace(',', '').astype(float)
df['defence_clearances'] = df['defence_clearances'].str.replace(',', '').astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 44 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Team                           20 non-null     object
#  1   category                       20 non-null     object
#  2   general_league_position        20 non-null     int64
#  3   finance _live_games_televised  20 non-null     int64
#  4   finance _tv_revenue            20 non-null     int64
#  5   general_matches_played         20 non-null     int64
#  6   general_won                    20 non-null     int64
#  7   general_draw                   20 non-null     int64
#  8   general_lost                   20 non-null     int64
#  9   attack_scored                  20 non-null     int64
#  10  defence_goals_conceeded        20 non-null     int64
#  11  general_goal_difference        20 non-null     int64
# ...

# %% [markdown]
# check for duplicate

# %%
df.duplicated().any()
# Out:
# False

# %% [markdown]
# check for null or nun

# %%
df.isnull().sum()
# Out:
# Team                             0
# category                         0
# general_league_position          0
# finance _live_games_televised    0
# finance _tv_revenue              0
# general_matches_played           0
# general_won                      0
# general_draw                     0
# general_lost                     0
# attack_scored                    0
# defence_goals_conceeded          0
# general_goal_difference          0
# general_points                   0
# general_squad_size               0
# general_squad_average_age        0
# general_squad_foreigners         0
# finance _team_market             0
# finance _market_average          0
# attack_passes                    0
# attack_passes_through            0
# attack_passes_long               0
# attack_passes_back               0
# attack_crosses                   0
# attack_corners_taken             0
# attack_shots                     0
# attack_shots_on_target           0
# attack_goals_headed              0
# ...

# %%
df.isna().sum()
# Out:
# Team                             0
# category                         0
# general_league_position          0
# finance _live_games_televised    0
# finance _tv_revenue              0
# general_matches_played           0
# general_won                      0
# general_draw                     0
# general_lost                     0
# attack_scored                    0
# defence_goals_conceeded          0
# general_goal_difference          0
# general_points                   0
# general_squad_size               0
# general_squad_average_age        0
# general_squad_foreigners         0
# finance _team_market             0
# finance _market_average          0
# attack_passes                    0
# attack_passes_through            0
# attack_passes_long               0
# attack_passes_back               0
# attack_crosses                   0
# attack_corners_taken             0
# attack_shots                     0
# attack_shots_on_target           0
# attack_goals_headed              0
# ...

# %%
df.head()
# Out:
#               Team                        category  general_league_position  \
# 0  Manchester City                Champions League                        1
# 1        Liverpool                Champions League                        2
# 2          Chelsea  Champions League Qualification                        3
# 3        Tottenham  Champions League Qualification                        4
# 4          Arsenal                   Europa League                        5
#
#    finance _live_games_televised  finance _tv_revenue  general_matches_played  \
# 0                             26            150986355                      38
# 1                             29            152425146                      38
# 2                             25            146030216                      38
# 3                             26            145230801                      38
# 4                             25            142193180                      38
#
# ...

# %% [markdown]
# no. 3

# %%
#import other libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='general_won', y="Team", data=df, order=df.sort_values('general_won').Team)
plt.show

# %%
plt.figure(figsize=(10, 10))
sns.barplot(x='attack_scored', y="Team", data=df, order=df.sort_values('attack_scored').Team)
plt.show

# %%
plt.figure(figsize=(10, 10))
sns.barplot(x='attack_posession', y="Team", data=df, order=df.sort_values('attack_posession').Team)
plt.show

# %% [markdown]
# number 4

# %%
df_defence = df[["defence_goals_conceeded","defence_saves","defence_blocks"]]
df_defence

# %%
plt.figure(figsize=(10, 10))
sns.barplot(x='defence_saves', y="Team", data=df, order=df.sort_values('defence_saves').Team)
plt.show

# %%
plt.figure(figsize=(10, 10))
sns.barplot(x='defence_blocks', y="Team", data=df, order=df.sort_values('defence_blocks').Team)
plt.show

# %%
plt.figure(figsize=(10, 10))
sns.barplot(x='defence_goals_conceeded', y="Team", data=df, order=df.sort_values('defence_goals_conceeded').Team)
plt.show

# %%
df_defence_sum = df_defence.sum(axis = 1, skipna = True)
df_defence_sum

# %%
df_defence['sum']=df_defence_sum
df_defence

# %%
df_defence.sort_values(by='sum', ascending= False).head(1)

# %%
df_defence.sort_values(by='defence_goals_conceeded', ascending= False).head(1)

# %%
df_defence.sort_values(by='defence_saves', ascending= False).head(1)

# %%
df_defence.sort_values(by='defence_blocks', ascending= False).head(1)

# %% [markdown]
# number 5

# %%
df_finance = df[['Team','finance _live_games_televised', 'finance _tv_revenue',
       'finance _team_market',
       'finance _market_average']]
df_finance.sort_values(by='finance _market_average', ascending=False).head()
